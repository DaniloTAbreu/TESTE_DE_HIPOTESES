# %% [markdown]
# # <font color='blue'>Problema de Estatística: diferença significativa na satisfação dos usuários entre as duas versões de software.
# </font>

# %% [markdown]
# # 1 - Definindo o problema de negócio

# %% [markdown]
# ### Uma empresa de software lançou duas versões de um novo aplicativo e quer comparar a satisfação dos usuários de cada versão. Eles coletaram dados de satisfação dos usuários em uma escala de 1 a 10 (1 = muito insatisfeito, 10 = muito satisfeito) para cada versão do aplicativo: Versão A e Versão B. A empresa quer saber se há uma diferença significativa na satisfação dos usuários entre as duas versões.

# %% [markdown]
# # 2 - Decisões

# %% [markdown]
# ### O problema de negócio é estatístico. O teste de Mann-Whitney é adequado aqui porque:
# ### - É um teste não paramétrico que não assume uma distribuição específica para os dados (por exemplo, normalidade).
# ### - Pode ser usado para comparar duas amostras independentes.

# %% [markdown]
# # 3 - Versão python e import dos pacotes utilizados

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.12.4

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
#!pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
#!pip install -q -U watermark

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Danilo Temerloglou de Abreu" --iversions
# Out:
# Author: Danilo Temerloglou de Abreu
#
# numpy     : 1.26.4
# pandas    : 2.2.2
# seaborn   : 0.13.2
# matplotlib: 3.8.4

# %% [markdown]
# # 4 - Criando os Conjuntos de dados

# %%
# Definindo os níveis de satisfação dos usuários para as duas versões do aplicativo
np.random.seed(42)
satisfacao_versao_a = np.random.randint(1, 11, 100)  # Escala de 1 a 10
satisfacao_versao_b = np.random.randint(1, 11, 100)  # Escala de 1 a 10

# Criando um DataFrame para facilitar a visualização
data = {
    'Versao': ['A']*100 + ['B']*100,
    'Satisfacao': np.concatenate([satisfacao_versao_a, satisfacao_versao_b])
}
df = pd.DataFrame(data)

# %%
# Visualizando as distribuições com boxplots
plt.figure(figsize=(12, 6))
sns.boxplot(x='Versao', y='Satisfacao', data=df, palette='Set2')
plt.title('Distribuição dos Níveis de Satisfação por Versão do Aplicativo')
plt.xlabel('Versão')
plt.ylabel('Nível de Satisfação')
plt.show()

# %%
# Visualizando as distribuições com gráficos de densidade
plt.figure(figsize=(12, 6))
sns.kdeplot(satisfacao_versao_a, label='Versão A', color='blue')
sns.kdeplot(satisfacao_versao_b, label='Versão B', color='green')
plt.title('Distribuição de Densidade dos Níveis de Satisfação por Versão do Aplicativo')
plt.xlabel('Nível de Satisfação')
plt.ylabel('Densidade')
plt.legend()
plt.show()

# %% [markdown]
# # 5 - Verificando as suposições, para aplicar o teste Kolmogorov-Smirnov:

# %% [markdown]
# ## 5.1 Não assume que os dados seguem uma distribuição específica

# %% [markdown]
# ### Não assumimos que os dados têm qualquer tipo de distribuição.

# %% [markdown]
# ## 5.2 Amostras independentes

# %% [markdown]
# ### Pode ser usado para comparar duas amostras independentes. Como geramos os dados aleatórios, podemos assumir que as duas amostras são independentes.

# %% [markdown]
# # 6 - Teste de hipóteses

# %% [markdown]
# ## 6.1 Teste Mann-Whitney

# %%
# Realizando o Teste de Mann-Whitney
stat, p = mannwhitneyu(satisfacao_versao_a, satisfacao_versao_b)

# %% [markdown]
# ## 6.2 Análise do resultado

# %% [markdown]
# ### O teste de Mann-Whitney retorna uma estatística U e um p-valor. Se o p-valor for menor que um nível de significância (comumente 0.05), rejeitamos a hipótese nula e concluímos que há uma diferença significativa nas distribuições dos níveis de satisfação.

# %%
print(f'Estatística Mann-Whitney: {stat}')
print(f'p-valor: {p}')
# Out:
# Estatística Mann-Whitney: 5715.0
# p-valor: 0.07922313813751446

# %%
# Interpretação dos resultados
if p < 0.05:
    print("Rejeitamos a hipótese nula. As distribuições dos níveis de satisfação são significativamente diferentes.")
else:
    print("Não rejeitamos a hipótese nula. Não há evidências suficientes para afirmar que as distribuições dos níveis de satisfação são diferentes.")
# Out:
# Não rejeitamos a hipótese nula. Não há evidências suficientes para afirmar que as distribuições dos níveis de satisfação são diferentes.

# %%
### Conclusão: 
### Não rejeitamos a hipótese nula. 
### Não há evidências estatísticas suficientes para afirmar que as distribuições dos níveis de satisfação das duas versões de software são diferentes.

# %% [markdown]
# # Fim
